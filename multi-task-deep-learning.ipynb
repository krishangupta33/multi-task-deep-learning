# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### 1. Data Exploration and Preprocessing:
# Understand your data. Handle missing values, encode categorical variables, and normalize numerical variables.

# %%
df = pd.read_csv("data/train.csv")

print(df.shape)
df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#check null values and print only which have null values
print(df.isnull().sum()[df.isnull().sum() > 0])

#print % of missing values in each column
print(df.isnull().mean()[df.isnull().sum() > 0] * 100)
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64
# LotFrontage     17.739726
# Alley           93.767123
# MasVnrType       0.547945
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %%
# dropping cols with missing values > 40%
cols_to_drop = df.columns[df.isnull().mean() > 0.4]
df = df.drop(cols_to_drop, axis=1)
#print % of missing values in each column
print(df.isnull().mean()[df.isnull().sum() > 0] * 100)
# Out:
# LotFrontage     17.739726
# MasVnrType       0.547945
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# dtype: float64

# %%
cols_to_impute = df.columns[df.isnull().mean() > 0]

#check col types
print(df[cols_to_impute].dtypes)

#impute float cols with mean and object cols with mode
for col in cols_to_impute:
    if df[col].dtype == 'float64':
        df[col] = df[col].fillna(df[col].mean())
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

print(df.isnull().mean()[df.isnull().sum() > 0] * 100)
# Out:
# LotFrontage     float64
# MasVnrType       object
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Electrical       object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# dtype: object
# Series([], dtype: float64)

# %%
#print all col names
print(df.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
#count plots
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(20, 5)) # Adjust figsize accordingly
axs = axs.flatten() # Flatten in case of a single row to ease indexing
object_cols = [col for col in df.columns if df[col].dtype == 'object']
for i, col in enumerate(object_cols):
    if i < 4: # Ensure we only plot the first 4 object columns
        df[col].value_counts().plot.bar(ax=axs[i])
        axs[i].set_title(col)
plt.tight_layout()
plt.show()

#histograms
fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(20, 5)) # Adjust figsize accordingly
axs = axs.flatten() # Flatten in case of a single row to ease indexing
float_cols = [col for col in df.columns if df[col].dtype == 'float64']
for i, col in enumerate(float_cols):
    if i < 4: # Ensure we only plot the first 4 float columns
        df[col].plot.hist(ax=axs[i], bins=20)
        axs[i].set_title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# You will create a new variable 'House Category' based on 'House Style', 'Bldg Type', 'Year Built', and 'Year Remod/Add' for the classification task.

# %%
cols_for_category = ["HouseStyle","BldgType","YearBuilt","YearRemodAdd"]

#data types of cols
print(df[cols_for_category].dtypes)

#display unique values in each col
for col in cols_for_category:
    print(col)
    print(df[col].unique())
# Out:
# HouseStyle      object
# BldgType        object
# YearBuilt        int64
# YearRemodAdd     int64
# dtype: object
# HouseStyle
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# BldgType
# ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# YearBuilt
# [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd
# [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]

# %% [markdown]
# ## Creating Categories from
# - House Style
# - Bldg Type
# - Year Built
# - Year Remod/Add

# %%
# Define category mapping
def categorize(row):
    if row['YearBuilt'] >= 1990 or row['YearRemodAdd'] >= 1990:
        era = 'Modern'
    elif row['YearBuilt'] < 1950 and row['YearRemodAdd'] < 1975:
        era = 'Historic'
    else:
        era = 'Mid-Century'

    if 'Twnhs' in row['BldgType']:
        type_ = 'Townhouse'
    elif row['BldgType'] in ['1Fam', '2fmCon']:
        type_ = 'Family Home'
    else:
        type_ = 'Multi-Unit'

    if row['HouseStyle'] in ['1Story', '1.5Fin', '2Story']:
        style_ = '1Story'
    elif row['HouseStyle'] in ['2Story', '2.5Fin', '2.5Unf']:
        style_ = '2Story'
    else:
        style_ = 'Other'

    return f"{era} {type_} {style_}"

# Apply categorization
df['house_category'] = df.apply(categorize, axis=1)

# %%
#plot house category
plt.figure()
df['house_category'].value_counts().plot.bar()
plt.title('house_category')
plt.show()

# %%
#print all cols
print(df.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'house_category'],
#       dtype='object')

# %%
#drop ID col
df = df.drop("Id", axis=1)

# %%
#print cols datatypes
for col in df.columns:
    print(col, df[col].dtype)
# Out:
# MSSubClass int64
# MSZoning object
# LotFrontage float64
# LotArea int64
# Street object
# LotShape object
# LandContour object
# Utilities object
# LotConfig object
# LandSlope object
# Neighborhood object
# Condition1 object
# Condition2 object
# BldgType object
# HouseStyle object
# OverallQual int64
# OverallCond int64
# YearBuilt int64
# YearRemodAdd int64
# RoofStyle object
# RoofMatl object
# Exterior1st object
# Exterior2nd object
# MasVnrType object
# MasVnrArea float64
# ExterQual object
# ExterCond object
# Foundation object
# BsmtQual object
# BsmtCond object
# BsmtExposure object
# BsmtFinType1 object
# BsmtFinSF1 int64
# BsmtFinType2 object
# BsmtFinSF2 int64
# BsmtUnfSF int64
# TotalBsmtSF int64
# Heating object
# HeatingQC object
# CentralAir object
# Electrical object
# 1stFlrSF int64
# 2ndFlrSF int64
# LowQualFinSF int64
# GrLivArea int64
# BsmtFullBath int64
# BsmtHalfBath int64
# FullBath int64
# HalfBath int64
# BedroomAbvGr int64
# KitchenAbvGr int64
# KitchenQual object
# TotRmsAbvGrd int64
# Functional object
# Fireplaces int64
# GarageType object
# GarageYrBlt float64
# GarageFinish object
# GarageCars int64
# GarageArea int64
# GarageQual object
# GarageCond object
# PavedDrive object
# WoodDeckSF int64
# OpenPorchSF int64
# EnclosedPorch int64
# 3SsnPorch int64
# ScreenPorch int64
# PoolArea int64
# MiscVal int64
# MoSold int64
# YrSold int64
# SaleType object
# SaleCondition object
# SalePrice int64
# house_category object

# %%
#correlation matrix
corr = df.corr()
plt.figure(figsize=(20,20))
plt.matshow(corr, fignum=1)
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.colorbar()
plt.show()
# Out:
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/161442637.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# Separate the input features (X) from the target variables (Y):

# %%
X = df.drop(['SalePrice', 'house_category'], axis=1)
y_price = df['SalePrice']
y_category = df['house_category']

# %%
#y_category datatype
print(y_price)
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# Perform any necessary data preprocessing, such as handling missing values, encoding categorical variables, and scaling numerical features. You can use techniques like imputation, one-hot encoding, and normalization/standardization.

# %%
#integer encoding y_category
y_category = y_category.astype('category')
y_category = y_category.cat.codes

#print head
print(y_category.head(10))

#y_category datatype
print(y_category.dtype)

#plot y_category value counts
plt.figure()
y_category.value_counts().plot.bar()
plt.title("y_category")
plt.show()
# Out:
# 0    10
# 1     4
# 2    10
# 3     0
# 4    10
# 5    10
# 6    10
# 7     4
# 8     0
# 9     2
# dtype: int8
# int8

# %%
#one hot encoding for X
X = pd.get_dummies(X, drop_first=True)
#print cols datatypes
print(X.dtypes.value_counts())
print("-----------------\n after conversion\n-----------------")
#convert to float64
for col in X.columns:
    X[col] = X[col].astype('float64')

print(X.dtypes.value_counts())
# Out:
# uint8      196
# int64       33
# float64      3
# dtype: int64
# -----------------
#  after conversion
# -----------------
# float64    232
# dtype: int64

# %%
X.shape
# Out:
# (1460, 232)

# %% [markdown]
# Split the data into training and testing sets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_price_train, y_price_test, y_category_train, y_category_test = train_test_split(
    X, y_price, y_category, test_size=0.2, random_state=42
)

# %% [markdown]
# Further split the training data into training and validation sets:

# %%
X_train, X_val, y_price_train, y_price_val, y_category_train, y_category_val = train_test_split(
    X_train, y_price_train, y_category_train, test_size=0.2, random_state=42
)

# %% [markdown]
# Create PyTorch datasets and data loaders for training, validation, and testing:

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# Create PyTorch datasets
train_dataset = TensorDataset(torch.tensor(X_train.values, dtype=torch.float32),
                              torch.tensor(y_price_train.values, dtype=torch.float32),
                              torch.tensor(y_category_train.values, dtype=torch.long))

val_dataset = TensorDataset(torch.tensor(X_val.values, dtype=torch.float32),
                            torch.tensor(y_price_val.values, dtype=torch.float32),
                            torch.tensor(y_category_val.values, dtype=torch.long))

test_dataset = TensorDataset(torch.tensor(X_test.values, dtype=torch.float32),
                             torch.tensor(y_price_test.values, dtype=torch.float32),
                             torch.tensor(y_category_test.values, dtype=torch.long))

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
input_size = X_train.shape[1]
num_classes = len(y_category.unique())
print(input_size, num_classes)
# Out:
# 232 17

# %% [markdown]
# # Hyperparameter Tuning Using Optuna

# %%
import optuna
import torch.nn as nn
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning import Callback

class HousingModel(pl.LightningModule):
    def __init__(self, trial: optuna.trial.Trial, input_size, num_classes):
        super().__init__()
        self.save_hyperparameters()

        # Hyperparameters
        hidden_size1 = trial.suggest_int('hidden_size1', 64, 512)
        hidden_size2 = trial.suggest_int('hidden_size2', 64, 512)
        lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
        optimizer_type = trial.suggest_categorical('optimizer_type', ['adam', 'sgd', 'rmsprop'])
        self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
        self.w_acc = 1 - self.w_loss

        # Model architecture
        self.hidden_layer1 = nn.Linear(input_size, hidden_size1)
        self.batch_norm1 = nn.BatchNorm1d(hidden_size1)
        self.hidden_layer2 = nn.Linear(hidden_size1, hidden_size2)
        self.batch_norm2 = nn.BatchNorm1d(hidden_size2)
        self.price_layer = nn.Linear(hidden_size2, 1)
        self.category_layer = nn.Linear(hidden_size2, num_classes)

        # Initialize weights
        self._init_weights()

        # Optimizer type
        self.optimizer_type = optimizer_type
        self.lr = lr

    def _init_weights(self):
        # Kaiming (He) initialization for layers with ReLU activation
        nn.init.kaiming_normal_(self.hidden_layer1.weight, mode='fan_out', nonlinearity='relu')
        nn.init.kaiming_normal_(self.hidden_layer2.weight, mode='fan_out', nonlinearity='relu')
        # For the output layers, you might use a simpler initialization since they might not be followed by ReLU
        nn.init.xavier_normal_(self.price_layer.weight)
        nn.init.xavier_normal_(self.category_layer.weight)

        
    def forward(self, x):
        x = self.hidden_layer1(x)
        x = self.batch_norm1(x)  # Apply BatchNorm after first linear layer
        # x = self.layer_norm1(x)  # Apply LayerNorm after BatchNorm
        x = torch.relu(x)
        
        x = self.hidden_layer2(x)
        x = self.batch_norm2(x)  # Apply BatchNorm after second linear layer
        # x = self.layer_norm2(x)  # Apply LayerNorm after BatchNorm
        x = torch.relu(x)
        
        price = self.price_layer(x)
        category = self.category_layer(x)
        return price, category
    
    def training_step(self, batch, batch_idx):
        x, y_price, y_category = batch
        price_pred, category_pred = self(x)
        
        price_loss = nn.MSELoss()(price_pred, y_price.view(-1, 1))
        category_loss = nn.CrossEntropyLoss()(category_pred, y_category)
        
        loss = self.w_loss * price_loss + self.w_acc * category_loss
        self.log('train_loss', loss)
        return loss
    

    
    def validation_step(self, batch, batch_idx):
        x, y_price, y_category = batch
        price_pred, category_pred = self(x)
        
        price_loss = nn.MSELoss()(price_pred, y_price.view(-1, 1))
        category_loss = nn.CrossEntropyLoss()(category_pred, y_category)

        loss = self.w_loss * price_loss + self.w_acc * category_loss

        accuracy = accuracy_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), normalize=True)
        precision = precision_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        recall = recall_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        f1 = f1_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)

   

        self.log('val_loss', loss)
        self.log('val_accuracy', accuracy)
        self.log('val_precision', precision)
        self.log('val_recall', recall)
        self.log('val_f1', f1)
        self.log('val_price_loss', price_loss)
        self.log('val_category_loss', category_loss)
    
    def test_step(self, batch, batch_idx):
        x, y_price, y_category = batch
        price_pred, category_pred = self(x)
        
        price_loss = nn.MSELoss()(price_pred, y_price.view(-1, 1))
        category_loss = nn.CrossEntropyLoss()(category_pred, y_category)

        loss = self.w_loss * price_loss + self.w_acc * category_loss

        accuracy = accuracy_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), normalize=True)
        precision = precision_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        recall = recall_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        f1 = f1_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        
        self.log('test_loss', loss)
        self.log('test_price_loss', price_loss)
        self.log('test_category_loss', category_loss)
        self.log('test_accuracy', accuracy)
        self.log('test_precision', precision)
        self.log('test_recall', recall)
        self.log('test_f1', f1)

    
    def configure_optimizers(self):
        if self.optimizer_type == 'adam':
            optimizer = torch.optim.Adam(self.parameters(), lr=self.lr)
        elif self.optimizer_type == 'sgd':
            optimizer = torch.optim.SGD(self.parameters(), lr=self.lr, momentum=0.9)
        elif self.optimizer_type == 'rmsprop':
            optimizer = torch.optim.RMSprop(self.parameters(), lr=self.lr)
        else:
            raise ValueError(f"Unsupported optimizer type: {self.optimizer_type}")
        return optimizer



def objective(trial: optuna.trial.Trial):
    # Define the hyperparameter search space
    model = HousingModel(trial, input_size=input_size, num_classes=num_classes)
    
    # Define logger and callbacks if needed
    logger = TensorBoardLogger("tb_logs", name="my_model_optuna")
    
    # Early stopping
    early_stopping = pl.callbacks.EarlyStopping('val_loss', patience=10)
    
    # Trainer
    trainer = pl.Trainer(
        logger=logger,
        callbacks=[early_stopping],
        max_epochs=20,
        enable_progress_bar=False
    )
    
    # Fit the model
    trainer.fit(model, train_loader, val_loader)
    
    # Evaluate and return the objective value
    val_loss = trainer.callback_metrics["val_loss"].item()
    return val_loss

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100, timeout=600)

print("Number of finished trials: ", len(study.trials))
print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-04-27 16:53:31,993] A new study created in memory with name: no-name-c24fd20b-92b8-4480-b940-72f520b57843
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 51.5 K
# 1 | batch_norm1    | BatchNorm1d | 442
# 2 | hidden_layer2  | Linear      | 64.8 K
# 3 | batch_norm2    | BatchNorm1d | 584
# 4 | price_layer    | Linear      | 293
# 5 | category_layer | Linear      | 5.0 K
# -----------------------------------------------
# 122 K     Trainable params
# 0         Non-trainable params
# 122 K     Total params
# 0.490     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:53:34,392] Trial 0 failed with parameters: {'hidden_size1': 221, 'hidden_size2': 292, 'lr': 0.0007227733534283469, 'optimizer_type': 'sgd', 'w_loss': 0.01031998849940834} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:53:34,393] Trial 0 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 41.2 K
# 1 | batch_norm1    | BatchNorm1d | 354
# 2 | hidden_layer2  | Linear      | 13.9 K
# 3 | batch_norm2    | BatchNorm1d | 156
# 4 | price_layer    | Linear      | 79
# 5 | category_layer | Linear      | 1.3 K
# -----------------------------------------------
# 57.1 K    Trainable params
# 0         Non-trainable params
# 57.1 K    Total params
# 0.228     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:53:39,423] Trial 1 finished with value: 427663840.0 and parameters: {'hidden_size1': 177, 'hidden_size2': 78, 'lr': 2.2754898880640544e-05, 'optimizer_type': 'sgd', 'w_loss': 0.03790893505819813}. Best is trial 1 with value: 427663840.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 20.3 K
# 1 | batch_norm1    | BatchNorm1d | 174
# 2 | hidden_layer2  | Linear      | 42.1 K
# 3 | batch_norm2    | BatchNorm1d | 956
# 4 | price_layer    | Linear      | 479
# 5 | category_layer | Linear      | 8.1 K
# -----------------------------------------------
# 72.1 K    Trainable params
# 0         Non-trainable params
# 72.1 K    Total params
# 0.288     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:53:40,175] Trial 2 failed with parameters: {'hidden_size1': 87, 'hidden_size2': 478, 'lr': 0.0673107829907073, 'optimizer_type': 'sgd', 'w_loss': 0.025621393071189918} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:53:40,175] Trial 2 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 68.5 K
# 1 | batch_norm1    | BatchNorm1d | 588
# 2 | hidden_layer2  | Linear      | 129 K
# 3 | batch_norm2    | BatchNorm1d | 876
# 4 | price_layer    | Linear      | 439
# 5 | category_layer | Linear      | 7.5 K
# -----------------------------------------------
# 207 K     Trainable params
# 0         Non-trainable params
# 207 K     Total params
# 0.828     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:53:45,191] Trial 3 finished with value: 870343872.0 and parameters: {'hidden_size1': 294, 'hidden_size2': 438, 'lr': 0.0003369122872749625, 'optimizer_type': 'rmsprop', 'w_loss': 0.021796379261861128}. Best is trial 1 with value: 427663840.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 118 K
# 1 | batch_norm1    | BatchNorm1d | 1.0 K
# 2 | hidden_layer2  | Linear      | 73.3 K
# 3 | batch_norm2    | BatchNorm1d | 288
# 4 | price_layer    | Linear      | 145
# 5 | category_layer | Linear      | 2.5 K
# -----------------------------------------------
# 195 K     Trainable params
# 0         Non-trainable params
# 195 K     Total params
# 0.782     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:53:46,395] Trial 4 failed with parameters: {'hidden_size1': 508, 'hidden_size2': 144, 'lr': 0.0034436151996101423, 'optimizer_type': 'sgd', 'w_loss': 0.03842480202042538} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:53:46,396] Trial 4 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 52.4 K
# 1 | batch_norm1    | BatchNorm1d | 450
# 2 | hidden_layer2  | Linear      | 50.9 K
# 3 | batch_norm2    | BatchNorm1d | 450
# 4 | price_layer    | Linear      | 226
# 5 | category_layer | Linear      | 3.8 K
# -----------------------------------------------
# 108 K     Trainable params
# 0         Non-trainable params
# 108 K     Total params
# 0.433     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:53:46,866] Trial 5 failed with parameters: {'hidden_size1': 225, 'hidden_size2': 225, 'lr': 0.0900837336430756, 'optimizer_type': 'sgd', 'w_loss': 0.03807911434274448} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:53:46,866] Trial 5 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 39.1 K
# 1 | batch_norm1    | BatchNorm1d | 336
# 2 | hidden_layer2  | Linear      | 65.4 K
# 3 | batch_norm2    | BatchNorm1d | 774
# 4 | price_layer    | Linear      | 388
# 5 | category_layer | Linear      | 6.6 K
# -----------------------------------------------
# 112 K     Trainable params
# 0         Non-trainable params
# 112 K     Total params
# 0.451     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:53:48,312] Trial 6 failed with parameters: {'hidden_size1': 168, 'hidden_size2': 387, 'lr': 7.523138212488019e-05, 'optimizer_type': 'sgd', 'w_loss': 0.09873267535738738} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:53:48,312] Trial 6 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 81.8 K
# 1 | batch_norm1    | BatchNorm1d | 702
# 2 | hidden_layer2  | Linear      | 179 K
# 3 | batch_norm2    | BatchNorm1d | 1.0 K
# 4 | price_layer    | Linear      | 511
# 5 | category_layer | Linear      | 8.7 K
# -----------------------------------------------
# 272 K     Trainable params
# 0         Non-trainable params
# 272 K     Total params
# 1.089     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:53:53,688] Trial 7 finished with value: 86130872.0 and parameters: {'hidden_size1': 351, 'hidden_size2': 510, 'lr': 0.017478122252257044, 'optimizer_type': 'rmsprop', 'w_loss': 0.013339776439961239}. Best is trial 7 with value: 86130872.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 102 K
# 1 | batch_norm1    | BatchNorm1d | 878
# 2 | hidden_layer2  | Linear      | 147 K
# 3 | batch_norm2    | BatchNorm1d | 670
# 4 | price_layer    | Linear      | 336
# 5 | category_layer | Linear      | 5.7 K
# -----------------------------------------------
# 257 K     Trainable params
# 0         Non-trainable params
# 257 K     Total params
# 1.029     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:53:54,399] Trial 8 failed with parameters: {'hidden_size1': 439, 'hidden_size2': 335, 'lr': 9.823093536031341e-05, 'optimizer_type': 'sgd', 'w_loss': 0.06411553780661423} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:53:54,399] Trial 8 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 35.4 K
# 1 | batch_norm1    | BatchNorm1d | 304
# 2 | hidden_layer2  | Linear      | 75.7 K
# 3 | batch_norm2    | BatchNorm1d | 990
# 4 | price_layer    | Linear      | 496
# 5 | category_layer | Linear      | 8.4 K
# -----------------------------------------------
# 121 K     Trainable params
# 0         Non-trainable params
# 121 K     Total params
# 0.485     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:53:59,964] Trial 9 finished with value: 69980248.0 and parameters: {'hidden_size1': 152, 'hidden_size2': 495, 'lr': 0.09933770172211563, 'optimizer_type': 'adam', 'w_loss': 0.0528856173253155}. Best is trial 9 with value: 69980248.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 96.5 K
# 1 | batch_norm1    | BatchNorm1d | 828
# 2 | hidden_layer2  | Linear      | 126 K
# 3 | batch_norm2    | BatchNorm1d | 612
# 4 | price_layer    | Linear      | 307
# 5 | category_layer | Linear      | 5.2 K
# -----------------------------------------------
# 230 K     Trainable params
# 0         Non-trainable params
# 230 K     Total params
# 0.922     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:54:00,704] Trial 10 failed with parameters: {'hidden_size1': 414, 'hidden_size2': 306, 'lr': 0.0002500244554666778, 'optimizer_type': 'sgd', 'w_loss': 0.01791460882675343} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:54:00,705] Trial 10 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 88.8 K
# 1 | batch_norm1    | BatchNorm1d | 762
# 2 | hidden_layer2  | Linear      | 98.6 K
# 3 | batch_norm2    | BatchNorm1d | 516
# 4 | price_layer    | Linear      | 259
# 5 | category_layer | Linear      | 4.4 K
# -----------------------------------------------
# 193 K     Trainable params
# 0         Non-trainable params
# 193 K     Total params
# 0.773     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:54:01,351] Trial 11 failed with parameters: {'hidden_size1': 381, 'hidden_size2': 258, 'lr': 0.03814710025887147, 'optimizer_type': 'sgd', 'w_loss': 0.043921708427455006} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:54:01,351] Trial 11 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 87.4 K
# 1 | batch_norm1    | BatchNorm1d | 750
# 2 | hidden_layer2  | Linear      | 136 K
# 3 | batch_norm2    | BatchNorm1d | 726
# 4 | price_layer    | Linear      | 364
# 5 | category_layer | Linear      | 6.2 K
# -----------------------------------------------
# 231 K     Trainable params
# 0         Non-trainable params
# 231 K     Total params
# 0.928     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:54:06,992] Trial 12 finished with value: 2890949120.0 and parameters: {'hidden_size1': 375, 'hidden_size2': 363, 'lr': 0.0003034505185996471, 'optimizer_type': 'adam', 'w_loss': 0.07237623534940964}. Best is trial 9 with value: 69980248.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 116 K
# 1 | batch_norm1    | BatchNorm1d | 996
# 2 | hidden_layer2  | Linear      | 254 K
# 3 | batch_norm2    | BatchNorm1d | 1.0 K
# 4 | price_layer    | Linear      | 512
# 5 | category_layer | Linear      | 8.7 K
# -----------------------------------------------
# 382 K     Trainable params
# 0         Non-trainable params
# 382 K     Total params
# 1.529     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:54:11,896] Trial 13 finished with value: 2838984448.0 and parameters: {'hidden_size1': 498, 'hidden_size2': 511, 'lr': 0.0045549516821669096, 'optimizer_type': 'rmsprop', 'w_loss': 0.0811156943589696}. Best is trial 9 with value: 69980248.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 57.3 K
# 1 | batch_norm1    | BatchNorm1d | 492
# 2 | hidden_layer2  | Linear      | 79.5 K
# 3 | batch_norm2    | BatchNorm1d | 644
# 4 | price_layer    | Linear      | 323
# 5 | category_layer | Linear      | 5.5 K
# -----------------------------------------------
# 143 K     Trainable params
# 0         Non-trainable params
# 143 K     Total params
# 0.575     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:54:16,637] Trial 14 finished with value: 2321548800.0 and parameters: {'hidden_size1': 246, 'hidden_size2': 322, 'lr': 0.01006658614238158, 'optimizer_type': 'rmsprop', 'w_loss': 0.08394432492017795}. Best is trial 9 with value: 69980248.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 40.5 K
# 1 | batch_norm1    | BatchNorm1d | 348
# 2 | hidden_layer2  | Linear      | 20.8 K
# 3 | batch_norm2    | BatchNorm1d | 238
# 4 | price_layer    | Linear      | 120
# 5 | category_layer | Linear      | 2.0 K
# -----------------------------------------------
# 64.1 K    Trainable params
# 0         Non-trainable params
# 64.1 K    Total params
# 0.256     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:54:17,252] Trial 15 failed with parameters: {'hidden_size1': 174, 'hidden_size2': 119, 'lr': 8.308366585314148e-05, 'optimizer_type': 'sgd', 'w_loss': 0.07132139865684481} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:54:17,253] Trial 15 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 33.8 K
# 1 | batch_norm1    | BatchNorm1d | 290
# 2 | hidden_layer2  | Linear      | 72.9 K
# 3 | batch_norm2    | BatchNorm1d | 998
# 4 | price_layer    | Linear      | 500
# 5 | category_layer | Linear      | 8.5 K
# -----------------------------------------------
# 116 K     Trainable params
# 0         Non-trainable params
# 116 K     Total params
# 0.468     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:54:21,981] Trial 16 finished with value: 3562167808.0 and parameters: {'hidden_size1': 145, 'hidden_size2': 499, 'lr': 1.876310061925161e-05, 'optimizer_type': 'rmsprop', 'w_loss': 0.08910857799031044}. Best is trial 9 with value: 69980248.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 46.1 K
# 1 | batch_norm1    | BatchNorm1d | 396
# 2 | hidden_layer2  | Linear      | 77.8 K
# 3 | batch_norm2    | BatchNorm1d | 782
# 4 | price_layer    | Linear      | 392
# 5 | category_layer | Linear      | 6.7 K
# -----------------------------------------------
# 132 K     Trainable params
# 0         Non-trainable params
# 132 K     Total params
# 0.529     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2024-04-27 16:54:27,591] Trial 17 finished with value: 3608159488.0 and parameters: {'hidden_size1': 198, 'hidden_size2': 391, 'lr': 4.977934064499874e-05, 'optimizer_type': 'adam', 'w_loss': 0.0902626517079918}. Best is trial 9 with value: 69980248.0.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 51.7 K
# 1 | batch_norm1    | BatchNorm1d | 444
# ...
# [W 2024-04-27 16:55:49,407] Trial 93 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 25.9 K
# 1 | batch_norm1    | BatchNorm1d | 222
# 2 | hidden_layer2  | Linear      | 32.8 K
# 3 | batch_norm2    | BatchNorm1d | 586
# 4 | price_layer    | Linear      | 294
# 5 | category_layer | Linear      | 5.0 K
# -----------------------------------------------
# 64.8 K    Trainable params
# 0         Non-trainable params
# 64.8 K    Total params
# 0.259     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:55:50,060] Trial 94 failed with parameters: {'hidden_size1': 111, 'hidden_size2': 293, 'lr': 0.08813777369994114, 'optimizer_type': 'sgd', 'w_loss': 0.0655339422135672} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:55:50,060] Trial 94 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 25.4 K
# 1 | batch_norm1    | BatchNorm1d | 218
# 2 | hidden_layer2  | Linear      | 30.4 K
# 3 | batch_norm2    | BatchNorm1d | 552
# 4 | price_layer    | Linear      | 277
# 5 | category_layer | Linear      | 4.7 K
# -----------------------------------------------
# 61.5 K    Trainable params
# 0         Non-trainable params
# 61.5 K    Total params
# 0.246     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:55:51,476] Trial 95 failed with parameters: {'hidden_size1': 109, 'hidden_size2': 276, 'lr': 0.03743463395780317, 'optimizer_type': 'sgd', 'w_loss': 0.042575592194714754} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:55:51,476] Trial 95 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 25.6 K
# 1 | batch_norm1    | BatchNorm1d | 220
# 2 | hidden_layer2  | Linear      | 33.0 K
# 3 | batch_norm2    | BatchNorm1d | 594
# 4 | price_layer    | Linear      | 298
# 5 | category_layer | Linear      | 5.1 K
# -----------------------------------------------
# 64.8 K    Trainable params
# 0         Non-trainable params
# 64.8 K    Total params
# 0.259     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:55:52,122] Trial 96 failed with parameters: {'hidden_size1': 110, 'hidden_size2': 297, 'lr': 0.07244966490823482, 'optimizer_type': 'sgd', 'w_loss': 0.041200715157219944} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:55:52,122] Trial 96 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 25.2 K
# 1 | batch_norm1    | BatchNorm1d | 216
# 2 | hidden_layer2  | Linear      | 31.8 K
# 3 | batch_norm2    | BatchNorm1d | 584
# 4 | price_layer    | Linear      | 293
# 5 | category_layer | Linear      | 5.0 K
# -----------------------------------------------
# 63.1 K    Trainable params
# 0         Non-trainable params
# 63.1 K    Total params
# 0.252     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:55:52,790] Trial 97 failed with parameters: {'hidden_size1': 108, 'hidden_size2': 292, 'lr': 0.08957501378085704, 'optimizer_type': 'sgd', 'w_loss': 0.04013163272256881} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:55:52,790] Trial 97 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 28.7 K
# 1 | batch_norm1    | BatchNorm1d | 246
# 2 | hidden_layer2  | Linear      | 20.8 K
# 3 | batch_norm2    | BatchNorm1d | 336
# 4 | price_layer    | Linear      | 169
# 5 | category_layer | Linear      | 2.9 K
# -----------------------------------------------
# 53.1 K    Trainable params
# 0         Non-trainable params
# 53.1 K    Total params
# 0.212     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:55:53,976] Trial 98 failed with parameters: {'hidden_size1': 123, 'hidden_size2': 168, 'lr': 0.08502268580992402, 'optimizer_type': 'sgd', 'w_loss': 0.06658498727987337} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:55:53,976] Trial 98 failed with value nan.
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   lr = trial.suggest_loguniform('lr', 1e-5, 1e-1)
# /var/folders/1p/q_9hhzqs0yddpgkxqm_hvtbc0000gn/T/ipykernel_67387/3364915325.py:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   self.w_loss = trial.suggest_uniform('w_loss', 0.01, 0.1)
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 27.0 K
# 1 | batch_norm1    | BatchNorm1d | 232
# 2 | hidden_layer2  | Linear      | 33.2 K
# 3 | batch_norm2    | BatchNorm1d | 568
# 4 | price_layer    | Linear      | 285
# 5 | category_layer | Linear      | 4.8 K
# -----------------------------------------------
# 66.2 K    Trainable params
# 0         Non-trainable params
# 66.2 K    Total params
# 0.265     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# [W 2024-04-27 16:55:54,624] Trial 99 failed with parameters: {'hidden_size1': 116, 'hidden_size2': 284, 'lr': 0.06815355882147851, 'optimizer_type': 'sgd', 'w_loss': 0.041409267892374084} because of the following error: The value nan is not acceptable.
# [W 2024-04-27 16:55:54,624] Trial 99 failed with value nan.
# Number of finished trials:  100
# Best trial:
#   Value:  69980248.0
#   Params:
#     hidden_size1: 152
#     hidden_size2: 495
#     lr: 0.09933770172211563
#     optimizer_type: adam
#     w_loss: 0.0528856173253155

# %% [markdown]
# # Code with Optimized Hyperparameters

# %%
import torch.nn as nn
import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger

class HousingModel(pl.LightningModule):
    def __init__(self, input_size, hidden_size1, hidden_size2, num_classes, lr=0.01, optimizer_type='adam', w_loss=0.07):
        super().__init__()
        self.save_hyperparameters()
        self.optimizer_type = optimizer_type
        self.lr = lr
        self.w_loss = w_loss

        self.hidden_layer1 = nn.Linear(input_size, hidden_size1)
        self.batch_norm1 = nn.BatchNorm1d(hidden_size1)  # BatchNorm for the first hidden layer
        # self.layer_norm1 = nn.LayerNorm(hidden_size1)  # LayerNorm for the first hidden layer
        self.hidden_layer2 = nn.Linear(hidden_size1, hidden_size2)
        self.batch_norm2 = nn.BatchNorm1d(hidden_size2)  # BatchNorm for the second hidden layer
        # self.layer_norm2 = nn.LayerNorm(hidden_size2)  # LayerNorm for the second hidden layer
        self.price_layer = nn.Linear(hidden_size2, 1)  # Regression output
        self.category_layer = nn.Linear(hidden_size2, num_classes)  # Classification output

    
        self.w_acc = 1-self.w_loss

        # Initialize weights
        self._init_weights()

    def _init_weights(self):
        # Kaiming (He) initialization for layers with ReLU activation
        nn.init.kaiming_normal_(self.hidden_layer1.weight, mode='fan_out', nonlinearity='relu')
        nn.init.kaiming_normal_(self.hidden_layer2.weight, mode='fan_out', nonlinearity='relu')
        # For the output layers, you might use a simpler initialization since they might not be followed by ReLU
        nn.init.xavier_normal_(self.price_layer.weight)
        nn.init.xavier_normal_(self.category_layer.weight)

        
    def forward(self, x):
        x = self.hidden_layer1(x)
        x = self.batch_norm1(x)  # Apply BatchNorm after first linear layer
        # x = self.layer_norm1(x)  # Apply LayerNorm after BatchNorm
        x = torch.relu(x)
        
        x = self.hidden_layer2(x)
        x = self.batch_norm2(x)  # Apply BatchNorm after second linear layer
        # x = self.layer_norm2(x)  # Apply LayerNorm after BatchNorm
        x = torch.relu(x)
        
        price = self.price_layer(x)
        category = self.category_layer(x)
        return price, category
    
    def training_step(self, batch, batch_idx):
        x, y_price, y_category = batch
        price_pred, category_pred = self(x)
        
        price_loss = nn.MSELoss()(price_pred, y_price.view(-1, 1))
        category_loss = nn.CrossEntropyLoss()(category_pred, y_category)
        
        loss = self.w_loss * price_loss + self.w_acc * category_loss
        self.log('train_loss', loss)
        return loss
    

    
    def validation_step(self, batch, batch_idx):
        x, y_price, y_category = batch
        price_pred, category_pred = self(x)
        
        price_loss = nn.MSELoss()(price_pred, y_price.view(-1, 1))
        category_loss = nn.CrossEntropyLoss()(category_pred, y_category)

        loss = self.w_loss * price_loss + self.w_acc * category_loss

        accuracy = accuracy_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), normalize=True)
        precision = precision_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        recall = recall_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        f1 = f1_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)

   

        self.log('val_loss', loss)
        self.log('val_accuracy', accuracy)
        self.log('val_precision', precision)
        self.log('val_recall', recall)
        self.log('val_f1', f1)
        self.log('val_price_loss', price_loss)
        self.log('val_category_loss', category_loss)
    
    def test_step(self, batch, batch_idx):
        x, y_price, y_category = batch
        price_pred, category_pred = self(x)
        
        price_loss = nn.MSELoss()(price_pred, y_price.view(-1, 1))
        category_loss = nn.CrossEntropyLoss()(category_pred, y_category)

        loss = self.w_loss * price_loss + self.w_acc * category_loss

        accuracy = accuracy_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), normalize=True)
        precision = precision_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        recall = recall_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        f1 = f1_score(y_category.cpu().numpy(), category_pred.argmax(dim=1).cpu().numpy(), average='weighted', zero_division=1)
        
        self.log('test_loss', loss)
        self.log('test_price_loss', price_loss)
        self.log('test_category_loss', category_loss)
        self.log('test_accuracy', accuracy)
        self.log('test_precision', precision)
        self.log('test_recall', recall)
        self.log('test_f1', f1)

    
    def configure_optimizers(self):
        if self.optimizer_type == 'adam':
            optimizer = torch.optim.Adam(self.parameters(), lr=self.hparams.lr)
        elif self.optimizer_type == 'sgd':
            optimizer = torch.optim.SGD(self.parameters(), lr=self.hparams.lr, momentum=0.9)
        elif self.optimizer_type == 'rmsprop':
            optimizer = torch.optim.RMSprop(self.parameters(), lr=self.hparams.lr)
        else:
            raise ValueError(f"Unsupported optimizer type: {self.optimizer_type}")
        return optimizer

# %%
# Initialize TensorBoardLogger
# logger = TensorBoardLogger("tb_logs", name="my_model")

# Optimized hyperparameters
#     - hidden_size1: 152
#     - hidden_size2: 495
#     - lr: 0.09933770172211563
#     - optimizer_type: adam
#     - w_loss: 0.0528856173253155


# Train the model using the Trainer from PyTorch Lightning
input_size = X_train.shape[1]
num_classes = len(y_category.unique())

#optimizer_type list 'adam','sgd','rmsprop'
model = HousingModel(input_size=input_size, hidden_size1=152, hidden_size2=495, num_classes=num_classes, lr=0.09933, optimizer_type='adam', w_loss=0.05288)

# trainer = pl.Trainer(max_epochs=20, enable_progress_bar=False, logger=logger)
trainer = pl.Trainer(max_epochs=20, enable_progress_bar=False)
trainer.fit(model, train_loader, val_loader)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type        | Params
# -----------------------------------------------
# 0 | hidden_layer1  | Linear      | 35.4 K
# 1 | batch_norm1    | BatchNorm1d | 304
# 2 | hidden_layer2  | Linear      | 75.7 K
# 3 | batch_norm2    | BatchNorm1d | 990
# 4 | price_layer    | Linear      | 496
# 5 | category_layer | Linear      | 8.4 K
# -----------------------------------------------
# 121 K     Trainable params
# 0         Non-trainable params
# 121 K     Total params
# 0.485     Total estimated model params size (MB)
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (30) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=20` reached.

# %% [markdown]
# # Evaluating on Validation Data

# %%
trainer.validate(model, val_loader)

#RMSE of val_price_loss
rmse = np.sqrt(trainer.logged_metrics['val_price_loss'])
print(f'RMSE Price Val: {rmse:.2f}')

#Accuracy of val_category_loss
accuracy = trainer.logged_metrics['val_accuracy']
print(f'Accuracy: {accuracy*100:.2f}')
# Out:
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       val_accuracy        │    0.5213675498962402     │
# │     val_category_loss     │     243.8235321044922     │
# │          val_f1           │     0.442777156829834     │
# │         val_loss          │        86227728.0         │
# │       val_precision       │    0.6365454196929932     │
# │      val_price_loss       │       1630626176.0        │
# │        val_recall         │    0.5213675498962402     │
# └───────────────────────────┴───────────────────────────┘
# RMSE Price Val: 40381.01
# Accuracy: 52.14

# %% [markdown]
# # Evaluating on Train Data

# %%
trainer.test(model, test_loader)

#RMSE of test_price_loss
rmse = np.sqrt(trainer.logged_metrics['test_price_loss'])
print(f'RMSE Price Test: {rmse:.2f}')

#Accuracy of test_category_loss
accuracy = trainer.logged_metrics['test_accuracy']
print(f'Accuracy: {accuracy*100:.2f}')
# Out:
# /Users/krishan/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:441: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │    0.45890411734580994    │
# │    test_category_loss     │    246.90370178222656     │
# │          test_f1          │    0.3783092200756073     │
# │         test_loss         │        109646928.0        │
# │      test_precision       │    0.5660455226898193     │
# │      test_price_loss      │       2073500672.0        │
# │        test_recall        │    0.45890411734580994    │
# └───────────────────────────┴───────────────────────────┘
# RMSE Price Test: 45535.71
# Accuracy: 45.89

# %%
#price mean median
price_mean = y_price.mean()
price_median = y_price.median()
print(f'Price Mean: {price_mean:.2f}')
print(f'Price Median: {price_median:.2f}')
# Out:
# Price Mean: 180921.20
# Price Median: 163000.00

# %% [markdown]
# # Saving the model

# %%
#save the model
torch.save(model.state_dict(), 'housing_model.pth')
